# %% [markdown]
# # 영상 데이터 예측 by 전이학습 template

# %% [markdown]
# # 데이터 준비

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.62.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (1.24.3)

# %%
# orginal shared link : https://drive.google.com/file/d/1_l-0FUDU1EovwlhnILnrrC0labjWtgCJ/view?usp=sharing
# !gdown https://drive.google.com/uc?id=1_l-0FUDU1EovwlhnILnrrC0labjWtgCJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_l-0FUDU1EovwlhnILnrrC0labjWtgCJ
# To: /content/cat_face_keypoint.zip
# 201MB [00:01, 152MB/s]

# %%
# !unzip cat_face_keypoint.zip
# Out:
# Archive:  cat_face_keypoint.zip
#   inflating: cat_image_and_keypoint.npy
#   inflating: memo.txt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img_size = 224

# %% [markdown]
# https://www.kaggle.com/crawford/cat-dataset 의
# 고양이 영상 파일과 레이블링 데이터를 읽고 numpy 파일로 저장해 두었다. <br>

# %%
numpy_data = np.load('cat_image_and_keypoint.npy', allow_pickle=True)
dic_data = numpy_data.item()
x = np.array(dic_data.get('imgs'))
y = np.array(dic_data.get('lmks'))

# %%
print(x.shape)
print(y.shape)
# Out:
# (1706, 224, 224, 3)
# (1706, 18)

# %% [markdown]
# ## 이미지 보기

# %%
plt.imshow(x[0])
plt.show()
print(y[0])
# Out:
# [ 59 135 128 137  85 177  32  93  19  48  50  64 172  72 205  67 188 106]

# %% [markdown]
# ## 키 포인트 보기

# %%
target_x = x[0]
target_y = y[0]

plt.imshow(target_x)

plt.scatter(target_y[0], target_y[1], color='yellow')
plt.text(target_y[0], target_y[1], 'left eye')
plt.scatter(target_y[2], target_y[3], color='yellow')
plt.text(target_y[2], target_y[3], 'right eye')
plt.scatter(target_y[4], target_y[5], color='yellow')
plt.text(target_y[4], target_y[5], 'nose')
plt.scatter(target_y[6], target_y[7], color='yellow')
plt.text(target_y[6], target_y[7], 'left ear 1')
plt.scatter(target_y[8], target_y[9], color='yellow')
plt.text(target_y[8], target_y[9], 'left ear 2')
plt.scatter(target_y[10], target_y[11], color='yellow')
plt.text(target_y[10], target_y[11], 'left ear 3')
plt.scatter(target_y[12], target_y[13], color='yellow')
plt.text(target_y[12], target_y[13], 'right ear 1')
plt.scatter(target_y[14], target_y[15], color='yellow')
plt.text(target_y[14], target_y[15], 'right ear 2')
plt.scatter(target_y[16], target_y[17], color='yellow')
plt.text(target_y[16], target_y[17], 'right ear 3')

plt.show()

# %% [markdown]
# ## 코만 추리기

# %% [markdown]
# 코에 해당하는 인덱스 4,5만 추림

# %%
y = y[:,4:6]

# %%
target_x = x[0]
target_y = y[0]

plt.imshow(target_x)
plt.scatter(target_y[0], target_y[1], color='yellow')
plt.show()

# %% [markdown]
# ## normalization

# %%
x = x / 255.

# %% [markdown]
# ## 데이터 분리

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, shuffle=True)

# %%
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (1364, 224, 224, 3)
# (1364, 2)
# (342, 224, 224, 3)
# (342, 2)

# %%
print(train_y[:10])
# Out:
# [[140 175]
#  [116 199]
#  [121 153]
#  [133 198]
#  [121 195]
#  [137 174]
#  [145 206]
#  [147 189]
#  [169 199]
#  [159 205]]

# %% [markdown]
# # Template

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras import models
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import mobilenet_v2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

conv_layers = mobilenet_v2.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
conv_layers.trainable = False

model = models.Sequential()

model.add(conv_layers)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(2))

model.summary()

model.compile(optimizer='Adam', loss='mse')


history = model.fit(train_x, train_y, epochs=100, batch_size=16, validation_split=0.1, verbose=1)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 62720)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               8028288
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 10,287,042
# Trainable params: 8,028,802
# Non-trainable params: 2,258,240
# _________________________________________________________________
# Epoch 1/100
# 77/77 [==============================] - 9s 71ms/step - loss: 25083.2090 - val_loss: 22023.4180
# Epoch 2/100
# 77/77 [==============================] - 4s 55ms/step - loss: 24053.9629 - val_loss: 20960.6641
# Epoch 3/100
# 77/77 [==============================] - 4s 55ms/step - loss: 22184.7812 - val_loss: 19528.2012
# Epoch 4/100
# 77/77 [==============================] - 4s 55ms/step - loss: 19466.6855 - val_loss: 14126.9277
# Epoch 5/100
# 77/77 [==============================] - 4s 54ms/step - loss: 16091.7910 - val_loss: 13716.4854
# Epoch 6/100
# 77/77 [==============================] - 4s 56ms/step - loss: 12453.6035 - val_loss: 9119.2295
# Epoch 7/100
# 77/77 [==============================] - 4s 56ms/step - loss: 9018.1338 - val_loss: 6920.8257
# Epoch 8/100
# 77/77 [==============================] - 4s 55ms/step - loss: 6129.8569 - val_loss: 4211.1636
# Epoch 9/100
# 77/77 [==============================] - 4s 54ms/step - loss: 3949.6919 - val_loss: 2690.4033
# Epoch 10/100
# 77/77 [==============================] - 4s 54ms/step - loss: 2394.6658 - val_loss: 1418.6268
# Epoch 11/100
# 77/77 [==============================] - 4s 54ms/step - loss: 1409.7399 - val_loss: 1107.0719
# Epoch 12/100
# 77/77 [==============================] - 4s 55ms/step - loss: 833.1196 - val_loss: 566.0522
# Epoch 13/100
# 77/77 [==============================] - 4s 54ms/step - loss: 506.2671 - val_loss: 358.6400
# Epoch 14/100
# 77/77 [==============================] - 4s 54ms/step - loss: 340.3495 - val_loss: 262.2803
# Epoch 15/100
# 77/77 [==============================] - 4s 54ms/step - loss: 219.2528 - val_loss: 184.7483
# Epoch 16/100
# 77/77 [==============================] - 4s 54ms/step - loss: 166.2515 - val_loss: 177.5783
# Epoch 17/100
# 77/77 [==============================] - 4s 54ms/step - loss: 123.3966 - val_loss: 158.2869
# Epoch 18/100
# 77/77 [==============================] - 4s 54ms/step - loss: 118.3551 - val_loss: 153.1877
# Epoch 19/100
# 77/77 [==============================] - 4s 54ms/step - loss: 112.9459 - val_loss: 151.2867
# Epoch 20/100
# 77/77 [==============================] - 4s 54ms/step - loss: 108.4337 - val_loss: 146.6273
# Epoch 21/100
# 77/77 [==============================] - 4s 54ms/step - loss: 101.6404 - val_loss: 247.9047
# Epoch 22/100
# 77/77 [==============================] - 4s 55ms/step - loss: 112.4452 - val_loss: 148.6503
# Epoch 23/100
# 77/77 [==============================] - 4s 54ms/step - loss: 111.9769 - val_loss: 146.4944
# Epoch 24/100
# 77/77 [==============================] - 4s 53ms/step - loss: 106.5880 - val_loss: 147.5299
# Epoch 25/100
# 77/77 [==============================] - 4s 55ms/step - loss: 97.5686 - val_loss: 159.9499
# Epoch 26/100
# 77/77 [==============================] - 4s 54ms/step - loss: 97.4081 - val_loss: 149.6448
# Epoch 27/100
# 77/77 [==============================] - 4s 54ms/step - loss: 82.5291 - val_loss: 141.5122
# Epoch 28/100
# 77/77 [==============================] - 4s 55ms/step - loss: 85.9545 - val_loss: 137.7014
# Epoch 29/100
# 77/77 [==============================] - 4s 54ms/step - loss: 87.0740 - val_loss: 140.1866
# Epoch 30/100
# 77/77 [==============================] - 4s 54ms/step - loss: 81.4944 - val_loss: 139.9079
# Epoch 31/100
# 77/77 [==============================] - 4s 54ms/step - loss: 75.4593 - val_loss: 143.5634
# Epoch 32/100
# 77/77 [==============================] - 4s 56ms/step - loss: 80.4558 - val_loss: 135.9443
# Epoch 33/100
# 77/77 [==============================] - 4s 55ms/step - loss: 83.1055 - val_loss: 138.5386
# Epoch 34/100
# 77/77 [==============================] - 4s 55ms/step - loss: 68.8406 - val_loss: 147.4576
# Epoch 35/100
# 77/77 [==============================] - 4s 54ms/step - loss: 73.8801 - val_loss: 142.2967
# Epoch 36/100
# 77/77 [==============================] - 4s 54ms/step - loss: 76.3250 - val_loss: 133.8091
# Epoch 37/100
# 77/77 [==============================] - 4s 54ms/step - loss: 70.1267 - val_loss: 137.0623
# Epoch 38/100
# 77/77 [==============================] - 4s 55ms/step - loss: 69.6531 - val_loss: 141.3628
# Epoch 39/100
# 77/77 [==============================] - 4s 55ms/step - loss: 86.3427 - val_loss: 139.8802
# Epoch 40/100
# 77/77 [==============================] - 4s 54ms/step - loss: 65.2675 - val_loss: 144.6084
# Epoch 41/100
# 77/77 [==============================] - 4s 55ms/step - loss: 66.8171 - val_loss: 154.0200
# Epoch 42/100
# 77/77 [==============================] - 4s 54ms/step - loss: 69.6331 - val_loss: 136.7169
# Epoch 43/100
# 77/77 [==============================] - 4s 58ms/step - loss: 62.3695 - val_loss: 142.1210
# Epoch 44/100
# 77/77 [==============================] - 4s 54ms/step - loss: 72.5047 - val_loss: 149.8592
# Epoch 45/100
# 77/77 [==============================] - 4s 54ms/step - loss: 73.9295 - val_loss: 139.5385
# Epoch 46/100
# 77/77 [==============================] - 4s 55ms/step - loss: 72.4160 - val_loss: 144.2236
# Epoch 47/100
# 77/77 [==============================] - 4s 54ms/step - loss: 82.5828 - val_loss: 138.8488
# Epoch 48/100
# 77/77 [==============================] - 4s 54ms/step - loss: 66.8605 - val_loss: 142.7889
# Epoch 49/100
# 77/77 [==============================] - 4s 53ms/step - loss: 69.9677 - val_loss: 139.7622
# Epoch 50/100
# 77/77 [==============================] - 4s 54ms/step - loss: 73.4744 - val_loss: 139.6098
# Epoch 51/100
# 77/77 [==============================] - 4s 54ms/step - loss: 65.4351 - val_loss: 138.1844
# Epoch 52/100
# 77/77 [==============================] - 4s 53ms/step - loss: 69.8093 - val_loss: 142.6497
# Epoch 53/100
# 77/77 [==============================] - 4s 55ms/step - loss: 67.9705 - val_loss: 154.8505
# Epoch 54/100
# 77/77 [==============================] - 4s 54ms/step - loss: 80.2414 - val_loss: 142.6909
# Epoch 55/100
# 77/77 [==============================] - 4s 55ms/step - loss: 56.5832 - val_loss: 144.8820
# Epoch 56/100
# 77/77 [==============================] - 4s 55ms/step - loss: 57.1877 - val_loss: 132.2337
# Epoch 57/100
# 77/77 [==============================] - 4s 55ms/step - loss: 67.6050 - val_loss: 143.2504
# Epoch 58/100
# 77/77 [==============================] - 4s 54ms/step - loss: 79.7541 - val_loss: 134.5968
# Epoch 59/100
# 77/77 [==============================] - 4s 55ms/step - loss: 74.9044 - val_loss: 139.6414
# Epoch 60/100
# 77/77 [==============================] - 4s 55ms/step - loss: 58.6381 - val_loss: 140.3764
# Epoch 61/100
# 77/77 [==============================] - 4s 55ms/step - loss: 65.8117 - val_loss: 146.0628
# Epoch 62/100
# 77/77 [==============================] - 4s 55ms/step - loss: 73.6995 - val_loss: 146.7256
# Epoch 63/100
# 77/77 [==============================] - 4s 55ms/step - loss: 65.5860 - val_loss: 142.3801
# Epoch 64/100
# 77/77 [==============================] - 4s 55ms/step - loss: 55.7413 - val_loss: 132.2692
# Epoch 65/100
# 77/77 [==============================] - 4s 54ms/step - loss: 54.1556 - val_loss: 142.3856
# Epoch 66/100
# 77/77 [==============================] - 4s 54ms/step - loss: 66.7437 - val_loss: 137.2999
# Epoch 67/100
# 77/77 [==============================] - 4s 54ms/step - loss: 61.7176 - val_loss: 138.4573
# Epoch 68/100
# 77/77 [==============================] - 4s 54ms/step - loss: 65.5338 - val_loss: 146.6115
# Epoch 69/100
# 77/77 [==============================] - 4s 54ms/step - loss: 71.3992 - val_loss: 143.9005
# Epoch 70/100
# 77/77 [==============================] - 4s 55ms/step - loss: 73.9700 - val_loss: 134.1149
# Epoch 71/100
# 77/77 [==============================] - 4s 55ms/step - loss: 67.9648 - val_loss: 148.8645
# Epoch 72/100
# 77/77 [==============================] - 4s 55ms/step - loss: 61.2133 - val_loss: 142.2358
# Epoch 73/100
# 77/77 [==============================] - 4s 55ms/step - loss: 65.5596 - val_loss: 135.4032
# Epoch 74/100
# 77/77 [==============================] - 4s 55ms/step - loss: 61.7547 - val_loss: 138.5468
# Epoch 75/100
# 77/77 [==============================] - 4s 56ms/step - loss: 66.6527 - val_loss: 154.3951
# Epoch 76/100
# 77/77 [==============================] - 4s 56ms/step - loss: 62.0253 - val_loss: 143.5901
# Epoch 77/100
# 77/77 [==============================] - 4s 57ms/step - loss: 52.4601 - val_loss: 138.7296
# Epoch 78/100
# 77/77 [==============================] - 4s 56ms/step - loss: 57.8269 - val_loss: 139.2245
# Epoch 79/100
# 77/77 [==============================] - 4s 55ms/step - loss: 60.9652 - val_loss: 136.1958
# Epoch 80/100
# 77/77 [==============================] - 4s 55ms/step - loss: 58.9198 - val_loss: 136.8243
# Epoch 81/100
# 77/77 [==============================] - 4s 55ms/step - loss: 66.2593 - val_loss: 135.5472
# Epoch 82/100
# 77/77 [==============================] - 4s 55ms/step - loss: 64.9849 - val_loss: 139.1590
# Epoch 83/100
# 77/77 [==============================] - 4s 54ms/step - loss: 60.2333 - val_loss: 134.6906
# Epoch 84/100
# 77/77 [==============================] - 4s 55ms/step - loss: 62.3410 - val_loss: 136.9603
# Epoch 85/100
# 77/77 [==============================] - 4s 55ms/step - loss: 46.5877 - val_loss: 134.6621
# Epoch 86/100
# 77/77 [==============================] - 4s 55ms/step - loss: 70.5531 - val_loss: 130.4389
# Epoch 87/100
# 77/77 [==============================] - 4s 55ms/step - loss: 67.6818 - val_loss: 135.0835
# Epoch 88/100
# 77/77 [==============================] - 4s 58ms/step - loss: 64.3166 - val_loss: 134.8710
# Epoch 89/100
# 77/77 [==============================] - 4s 55ms/step - loss: 63.6321 - val_loss: 136.5950
# Epoch 90/100
# 77/77 [==============================] - 4s 56ms/step - loss: 61.9680 - val_loss: 138.2338
# Epoch 91/100
# 77/77 [==============================] - 4s 56ms/step - loss: 61.6700 - val_loss: 133.3291
# Epoch 92/100
# 77/77 [==============================] - 4s 56ms/step - loss: 60.8939 - val_loss: 135.9982
# Epoch 93/100
# 77/77 [==============================] - 4s 56ms/step - loss: 62.2857 - val_loss: 138.2026
# Epoch 94/100
# 77/77 [==============================] - 4s 55ms/step - loss: 62.9781 - val_loss: 130.3011
# Epoch 95/100
# 77/77 [==============================] - 4s 56ms/step - loss: 56.0107 - val_loss: 133.0349
# Epoch 96/100
# 77/77 [==============================] - 4s 56ms/step - loss: 53.4983 - val_loss: 133.3777
# Epoch 97/100
# 77/77 [==============================] - 4s 55ms/step - loss: 62.7445 - val_loss: 133.7097
# Epoch 98/100
# 77/77 [==============================] - 4s 55ms/step - loss: 54.5809 - val_loss: 136.0716
# Epoch 99/100
# 77/77 [==============================] - 4s 54ms/step - loss: 55.3778 - val_loss: 132.8920
# Epoch 100/100
# 77/77 [==============================] - 4s 56ms/step - loss: 60.0106 - val_loss: 138.6405

# %% [markdown]
# # 결과 보기

# %%
predicted = model.predict(test_x[:16])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb48eda9950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
for i in range(16):
  plt.imshow(test_x[i])
  plt.scatter(predicted[i][0], predicted[i][1], color='yellow')
  plt.show()
