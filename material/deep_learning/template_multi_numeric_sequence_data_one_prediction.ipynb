# %% [markdown]
# # 다중 숫자 순차열 데이터 단일 예측 Template

# %% [markdown]
# # 데이터 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 기반 숫자열 생성

# %%
numbers = np.zeros((2000,2))
numbers[:,0] = np.sin(np.arange(0,1000,0.5))
numbers[:,1] = np.cos(np.arange(0,1000,0.5))

# %%
plt.plot(numbers[:100,0])
plt.plot(numbers[:100,1])
plt.show()

# %%
SEQUENCE_LENGTH = 5
OFFSET = 1

# %% [markdown]
# ## 입출력 데이터 생성
#
# [12345678901234567890, 34567890123456789012]의 숫자열 2개로 다음의 입출력 데이터를 생성한다.
# ```
# [12345, 34567] -> 6
# [23456, 45678] -> 7
# [34567, 56789] -> 8
# ...
# [56789, 78901] -> 0
# ```

# %%
raw_x = []
raw_y = []

for i in range(len(numbers)):
  if i+SEQUENCE_LENGTH+OFFSET >= len(numbers): break
  raw_x.append(numbers[i:i+SEQUENCE_LENGTH,:])
  raw_y.append([numbers[i+SEQUENCE_LENGTH+OFFSET-1,0]])
#              0         1              
#              01234567890123456789
# numbers[0] = 12345678901234567890
#                 i = 3
#                 <-x0>   = [3:8] = 45678
#                      y  = [8]   = 9
# numbers[1] = 34567890123456789012
#                 i = 3
#                 <-x1>   = [3:8] = 67890

# %%
print(len(raw_x))
# len(raw_x) = 1994 = len(numbers) - SEQUENCE_LENGTH - OFFSET = 2000 - 5 - 1
# Out:
# 1994

# %% [markdown]
# ## 데이터를 2차원 벡터화 하기
#
# RNN은 2차원 입력을 전제로 한다. 다중 숫자열은 그 자체로 2차원 데이터이다. 따로 해줄 것은 없다.

# %%
print(raw_x[0])
print(raw_y[0])
# Out:
# [[ 0.          1.        ]
#  [ 0.47942554  0.87758256]
#  [ 0.84147098  0.54030231]
#  [ 0.99749499  0.0707372 ]
#  [ 0.90929743 -0.41614684]]
# [0.5984721441039565]

# %%
x = np.array(raw_x)
y = np.array(raw_y)
print(x.shape)
print(y.shape)

split_at = int(len(x)*0.9)
(train_x, test_x) = x[:split_at], x[split_at:]
(train_y, test_y) = y[:split_at], y[split_at:]

print("Training Data:")
print(train_x.shape)
print(train_y.shape)

print("Test Data:")
print(test_x.shape)
print(test_y.shape)
# Out:
# (1994, 5, 2)
# (1994, 1)
# Training Data:
# (1794, 5, 2)
# (1794, 1)
# Test Data:
# (200, 5, 2)
# (200, 1)

# %% [markdown]
# 준비된 데이터는 다음과 같습니다.

# %%
print("train_x[0]\n", train_x[0])
print()
print("train_y[0]\n", train_y[0])

plt.plot(train_x[0].T[0], '.')
plt.plot(train_x[0].T[1], '.')
plt.plot([len(train_x[0])], train_y[0], 'x')

plt.show()
# Out:
# train_x[0]
#  [[ 0.          1.        ]
#  [ 0.47942554  0.87758256]
#  [ 0.84147098  0.54030231]
#  [ 0.99749499  0.0707372 ]
#  [ 0.90929743 -0.41614684]]
#
# train_y[0]
#  [0.59847214]

# %% [markdown]
# # Template

# %% [markdown]
# ## LSTM

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, RepeatVector, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU

input_shape = train_x.shape[1:]
# input_shape = (5,2)

model = keras.Sequential()
model.add(LSTM(128, input_shape=input_shape))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=10, verbose=0, validation_split=0.1, batch_size=128)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()



loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)



y_ = model.predict(test_x)
plt.scatter(test_y, y_)
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               67072
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 67,201
# Trainable params: 67,201
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6860e-06 - mae: 0.0019
# loss= 4.686014563048957e-06
# mae= 0.0019018682651221752

# %% [markdown]
# ## GRU

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, RepeatVector, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU

input_shape = train_x.shape[1:]
# input_shape = (5,2)

model = keras.Sequential()
model.add(GRU(128, input_shape=input_shape))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=10, verbose=0, validation_split=0.1, batch_size=128)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()



loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)



y_ = model.predict(test_x)
plt.scatter(test_y, y_)
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 50,817
# Trainable params: 50,817
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1316e-07 - mae: 3.7769e-04
# loss= 2.1316091647349822e-07
# mae= 0.00037768558831885457

# %% [markdown]
# ## Bidirectional + LSTM

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, RepeatVector, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU

input_shape = train_x.shape[1:]
# input_shape = (5,2)

model = keras.Sequential()
model.add(Bidirectional(LSTM(128), input_shape=input_shape))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=10, verbose=0, validation_split=0.1, batch_size=128)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()



loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)



y_ = model.predict(test_x)
plt.scatter(test_y, y_)
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 256)               134144
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 134,401
# Trainable params: 134,401
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5274e-06 - mae: 0.0010
# loss= 1.5274277984644868e-06
# mae= 0.001023567863740027

# %% [markdown]
# ## Bidirectional + GRU

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, RepeatVector, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU

input_shape = train_x.shape[1:]
# input_shape = (5,2)

model = keras.Sequential()
model.add(Bidirectional(GRU(128), input_shape=input_shape))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=10, verbose=0, validation_split=0.1, batch_size=128)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()



loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)



y_ = model.predict(test_x)
plt.scatter(test_y, y_)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 256)               101376
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 101,633
# Trainable params: 101,633
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 3ms/step - loss: 3.0479e-07 - mae: 4.7798e-04
# loss= 3.0479307611130935e-07
# mae= 0.00047797884326428175

# %% [markdown]
# ## stacked

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, RepeatVector, Flatten
from tensorflow.keras.layers import Bidirectional, LSTM, GRU

input_shape = train_x.shape[1:]
# input_shape = (5,2)

model = keras.Sequential()
model.add(LSTM(128, input_shape=input_shape, return_sequences=True))
model.add(LSTM(128))
model.add(Flatten())
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=10, verbose=0, validation_split=0.1, batch_size=128)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()



loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)



y_ = model.predict(test_x)
plt.scatter(test_y, y_)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 5, 128)            67072
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 198,785
# Trainable params: 198,785
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3208e-06 - mae: 0.0023
# loss= 6.3207871789927594e-06
# mae= 0.0022625208366662264
